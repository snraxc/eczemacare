# %%
# !/opt/anaconda3/envs/python310/bin/python -m uvicorn main:app --host 127.0.0.1 --port 8000 --reload
# Out:
# INFO:     Will watch for changes in these directories: ['/Users/daniel/Desktop/Canada Education/Daniel/Personal Project/AI/web/eczema']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [76223] using StatReload
# Loading ML Model...
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:     Started server process [76226]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
